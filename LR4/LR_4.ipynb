# %%
import matplotlib.pyplot as plt, pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('./rpi_data_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date  \
# 0           0      9.416              80.21           205.95  2021-03-25
# 1           1      7.949              85.32           219.97  2021-03-25
# 2           2      8.192              89.64           213.21  2021-03-25
# 3           3      9.408             549.64           175.84  2021-03-25
# 4           4      9.580             543.48           217.32  2021-03-25
#
#        Time
# 0  18:42:29
# 1  18:42:47
# 2  18:43:05
# 3  18:43:24
# 4  18:43:39

# %%
df.tail()
# Out:
#      Unnamed: 0  Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date  \
# 96           96      7.634             537.15           207.07  2021-03-25
# 97           97     10.782             535.54           198.39  2021-03-25
# 98           98      8.681              85.96           211.79  2021-03-25
# 99           99     10.168              83.02           219.93  2021-03-25
# 100         100      7.296              88.54           193.98  2021-03-25
#
#          Time
# 96   19:09:26
# 97   19:09:40
# 98   19:09:54
# 99   19:10:13
# 100  19:10:31

# %%
df.describe()
# Out:
#        Unnamed: 0   Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)
# count  101.000000  101.000000          101.00000       101.000000
# mean    50.000000    8.674465          264.39802       207.312871
# std     29.300171    1.405341          221.11458        23.043796
# min      0.000000    5.598000           57.73000        68.400000
# 25%     25.000000    7.634000           78.92000       199.080000
# 50%     50.000000    8.788000           87.66000       210.150000
# 75%     75.000000    9.532000          521.05000       221.010000
# max    100.000000   11.926000          574.18000       236.110000

# %%
df['rounded_ping'] = df['Ping (ms)'].round(2)
df.head()
# Out:
#    Unnamed: 0  Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date  \
# 0           0      9.416              80.21           205.95  2021-03-25
# 1           1      7.949              85.32           219.97  2021-03-25
# 2           2      8.192              89.64           213.21  2021-03-25
# 3           3      9.408             549.64           175.84  2021-03-25
# 4           4      9.580             543.48           217.32  2021-03-25
#
#        Time  rounded_ping
# 0  18:42:29          9.42
# 1  18:42:47          7.95
# 2  18:43:05          8.19
# 3  18:43:24          9.41
# 4  18:43:39          9.58

# %%
df['diff'] = df['rounded_ping'] - 5
df.head()
# Out:
#    Unnamed: 0  Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date  \
# 0           0      9.416              80.21           205.95  2021-03-25
# 1           1      7.949              85.32           219.97  2021-03-25
# 2           2      8.192              89.64           213.21  2021-03-25
# 3           3      9.408             549.64           175.84  2021-03-25
# 4           4      9.580             543.48           217.32  2021-03-25
#
#        Time  rounded_ping  diff
# 0  18:42:29          9.42  4.42
# 1  18:42:47          7.95  2.95
# 2  18:43:05          8.19  3.19
# 3  18:43:24          9.41  4.41
# 4  18:43:39          9.58  4.58

# %%
rndd = df['rounded_ping']
print(f'There are {rndd.count()} records in the data')
print(f'The mean of the distribution is {rndd.mean():.2f} and the median is {rndd.median()}')
print(f'The standart deviation of distribution is {rndd.std():.3f}')
print(f'The minimum value is {rndd.min()}, the maximum value is {rndd.max()}, and the range is {rndd.max() - rndd.min()}')
# Out:
# There are 101 records in the data
# The mean of the distribution is 8.67 and the median is 8.79
# The standart deviation of distribution is 1.406
# The minimum value is 5.6, the maximum value is 11.93, and the range is 6.33

# %%
freq = rndd.value_counts()
freq = freq.to_frame().reset_index()
freq.columns = ['value', 'freq']
freq.head()
# Out:
#    value  freq
# 0   9.38     2
# 1   8.73     2
# 2   8.69     2
# 3   9.08     2
# 4   8.74     2

# %%
plt.figure(figsize = (10, 10))
plt.plot(freq.value, freq.freq, 'o', markersize = 5, color = 'b')
plt.xlabel('Ping')
plt.ylabel('Frequncy')
# Out:
# Text(0, 0.5, 'Frequncy')
